# %%
# !pip install fasteda -q
# Out:
#   Preparing metadata (setup.py) ... done
# ...

# %%
import pandas as pd
import numpy as np
from fasteda import fast_eda

# %%
train_csv = pd.read_csv("/content/train_clean.csv")

# %%
train_csv.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex       Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    1 -0.565736      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  0.663861      1
# 2                             Heikkinen, Miss. Laina    0 -0.258337      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  0.433312      1
# 4                           Allen, Mr. William Henry    1  0.433312      0
#
#    Parch            Ticket      Fare Embarked
# 0      0         A/5 21171 -0.879741        S
# 1      0          PC 17599  1.361220        C
# 2      0  STON/O2. 3101282 -0.798540        S
# 3      0            113803  1.062038        S
# 4      0            373450 -0.784179        S

# %%
fast_eda(train_csv, target="Survived")
# Out:
# DataFrame Head:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name  Sex       Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    1 -0.565736      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  0.663861      1
# 2                             Heikkinen, Miss. Laina    0 -0.258337      0
#
#    Parch            Ticket      Fare Embarked
# 0      0         A/5 21171 -0.879741        S
# 1      0          PC 17599  1.361220        C
# 2      0  STON/O2. 3101282 -0.798540        S
# DataFrame Tail:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# ...
